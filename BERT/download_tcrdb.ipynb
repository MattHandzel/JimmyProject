# %%
import requests
import re, os, threading
t = '<ul data-v-c3a807e0=""><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA330606.tsv">PRJNA330606</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA393498.tsv">PRJNA393498</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA280417.tsv">PRJNA280417</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA506151.tsv">PRJNA506151</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA321261.tsv">PRJNA321261</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA312319.tsv">PRJNA312319</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA325496.tsv">PRJNA325496</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA395098.tsv">PRJNA395098</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA390125.tsv">PRJNA390125</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA301507.tsv">PRJNA301507</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA316033.tsv">PRJNA316033</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA427746.tsv">PRJNA427746</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA79519.tsv">PRJNA79519</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA325416.tsv">PRJNA325416</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA203441.tsv">PRJNA203441</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA229070.tsv">PRJNA229070</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJEB33490.tsv">PRJEB33490</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA312766.tsv">PRJNA312766</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA79707.tsv">PRJNA79707</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA298417.tsv">PRJNA298417</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA297261.tsv">PRJNA297261</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA385561.tsv">PRJNA385561</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA491656.tsv">PRJNA491656</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA318495.tsv">PRJNA318495</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA318421.tsv">PRJNA318421</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA389805.tsv">PRJNA389805</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA300878.tsv">PRJNA300878</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA516984.tsv">PRJNA516984</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA510967.tsv">PRJNA510967</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA509233.tsv">PRJNA509233</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA493983.tsv">PRJNA493983</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA450033.tsv">PRJNA450033</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA494572.tsv">PRJNA494572</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA391483.tsv">PRJNA391483</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA544470.tsv">PRJNA544470</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA477518.tsv">PRJNA477518</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA356992.tsv">PRJNA356992</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA422601.tsv">PRJNA422601</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA273698.tsv">PRJNA273698</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA214848.tsv">PRJNA214848</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA577520.tsv">PRJNA577520</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA377207.tsv">PRJNA377207</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA376866.tsv">PRJNA376866</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA389678.tsv">PRJNA389678</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA544699.tsv">PRJNA544699</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA495603.tsv">PRJNA495603</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA374973.tsv">PRJNA374973</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA412739.tsv">PRJNA412739</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA329041.tsv">PRJNA329041</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA579190.tsv">PRJNA579190</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA258001.tsv">PRJNA258001</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA393071.tsv">PRJNA393071</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA315543.tsv">PRJNA315543</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA473147.tsv">PRJNA473147</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA517192.tsv">PRJNA517192</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA577794.tsv">PRJNA577794</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA633317.tsv">PRJNA633317</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA516296.tsv">PRJNA516296</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA436233.tsv">PRJNA436233</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA429872.tsv">PRJNA429872</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJEB38339.tsv">PRJEB38339</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA449605.tsv">PRJNA449605</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA208615.tsv">PRJNA208615</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA377124.tsv">PRJNA377124</a></li><li data-v-c3a807e0=""><a data-v-c3a807e0="" href="http://bioinfo.life.hust.edu.cn/TCRdb/Download/PRJNA602827.tsv">PRJNA602827</a></li></ul>'
pattern = re.compile("href=\".*?\"")
a  = pattern.findall(t)

def download(string, filename):
  r = requests.get(string)
  with open(filename, "wb") as code:
    code.write(r.content)

for s in a:
    s = (s[6:-1])
    if s.split("/")[-1] not in os.listdir("./"):
      threading.Thread(target=download, args=(s, s.split("/")[-1])).start()
